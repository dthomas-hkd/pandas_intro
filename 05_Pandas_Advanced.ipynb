# %% [markdown]
# # Pandas: Advanced Topics

# %% [markdown]
# ## Adding new Columns to a DataFrame

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic["Zeros"] = "Zero"

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero

# %%
titanic.Ones = 1

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero

# %%
titanic.Ones
# Out:
# 1

# %% [markdown]
# ## Arithmetic Operations

# %%
import numpy as np

# %% [markdown]
# ### Add/Sub/Mul/Div of Columns

# %%
titanic.sibsp + titanic.parch
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic.sibsp.add(titanic.parch)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Length: 891, dtype: int64

# %%
titanic["no_relat"] = titanic.sibsp.add(titanic.parch)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero
#
#    no_relat
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0

# %%
sales = pd.read_csv("sales.csv", index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.Mon + sales.Thu
# Out:
# Steven      NaN
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
sales.Mon.add(sales.Thu, fill_value=0)
# Out:
# Steven     34.0
# Mike      132.0
# Andi       25.0
# Paul      132.0
# dtype: float64

# %%
sales["perc_Bonus"] = [0.12, 0.15, 0.10, 0.20]

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus
# Steven   34   27   15   NaN   33        0.12
# Mike     45    9   74  87.0   12        0.15
# Andi     17   33   54   8.0   29        0.10
# Paul     87   67   27  45.0    7        0.20

# %%
sales.Thu * sales.perc_Bonus
# Out:
# Steven      NaN
# Mike      13.05
# Andi       0.80
# Paul       9.00
# dtype: float64

# %%
sales.Thu.mul(sales.perc_Bonus, fill_value=0)
# Out:
# Steven     0.00
# Mike      13.05
# Andi       0.80
# Paul       9.00
# dtype: float64

# %%
sales.iloc[:, :-1].sum(axis = 1).mul(sales.perc_Bonus)
# Out:
# Steven    13.08
# Mike      34.05
# Andi      14.10
# Paul      46.60
# dtype: float64

# %%
sales["Bonus"] = sales.iloc[:, :-1].sum(axis = 1).mul(sales.perc_Bonus)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus  Bonus
# Steven   34   27   15   NaN   33        0.12  13.08
# Mike     45    9   74  87.0   12        0.15  34.05
# Andi     17   33   54   8.0   29        0.10  14.10
# Paul     87   67   27  45.0    7        0.20  46.60

# %% [markdown]
# ### Add/Sub/Mul/Div with Scalar Value

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero
#
#    no_relat
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0

# %%
1912 - titanic.age
# Out:
# 0      1890.0
# 1      1874.0
# 2      1886.0
# 3      1877.0
# 4      1877.0
#         ...
# 886    1885.0
# 887    1893.0
# 888       NaN
# 889    1886.0
# 890    1880.0
# Name: age, Length: 891, dtype: float64

# %%
titanic["YoB"] = titanic.age.sub(1912).mul(-1)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero
#
#    no_relat     YoB
# 0         1  1890.0
# 1         1  1874.0
# 2         0  1886.0
# 3         1  1877.0
# 4         0  1877.0

# %%
fx_rate = 1.1

# %%
titanic["EUR_fare"] = titanic.fare.div(fx_rate)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck Zeros  \
# 0         0       3    male  22.0      1      0   7.2500        S  NaN  Zero
# 1         1       1  female  38.0      1      0  71.2833        C    C  Zero
# 2         1       3  female  26.0      0      0   7.9250        S  NaN  Zero
# 3         1       1  female  35.0      1      0  53.1000        S    C  Zero
# 4         0       3    male  35.0      0      0   8.0500        S  NaN  Zero
#
#    no_relat     YoB   EUR_fare
# 0         1  1890.0   6.590909
# 1         1  1874.0  64.803000
# 2         0  1886.0   7.204545
# 3         1  1877.0  48.272727
# 4         0  1877.0   7.318182

# %%
titanic.drop(columns = ["sibsp", "parch", "deck", "YoB", "EUR_fare"], inplace =True)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age     fare embarked Zeros  no_relat
# 0         0       3    male  22.0   7.2500        S  Zero         1
# 1         1       1  female  38.0  71.2833        C  Zero         1
# 2         1       3  female  26.0   7.9250        S  Zero         0
# 3         1       1  female  35.0  53.1000        S  Zero         1
# 4         0       3    male  35.0   8.0500        S  Zero         0

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri  perc_Bonus  Bonus
# Steven   34   27   15   NaN   33        0.12  13.08
# Mike     45    9   74  87.0   12        0.15  34.05
# Andi     17   33   54   8.0   29        0.10  14.10
# Paul     87   67   27  45.0    7        0.20  46.60

# %%
fixed_costs = 5

# %%
sales.iloc[:, :-2].sub(fixed_costs, fill_value = 0)
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   29   22   10  -5.0   28
# Mike     40    4   69  82.0    7
# Andi     12   28   49   3.0   24
# Paul     82   62   22  40.0    2

# %%
perc_Bonus = 0.1

# %%
sales.iloc[:, :-2].mul(perc_Bonus, fill_value = 0)
# Out:
#         Mon  Tue  Wed  Thu  Fri
# Steven  3.4  2.7  1.5  0.0  3.3
# Mike    4.5  0.9  7.4  8.7  1.2
# Andi    1.7  3.3  5.4  0.8  2.9
# Paul    8.7  6.7  2.7  4.5  0.7

# %%
sales.iloc[:,:-2]
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %% [markdown]
# ### Manipulating Elements in a DataFrame

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[1, "age"] = 40
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  40.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.iloc[1, 3] = 41
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  41.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[1:3, "age"] = 42
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  42.0      0      0   7.9250        S  NaN
# 3         1       1  female  42.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[:, "age"] = titanic.loc[:, "age"] * 12
titanic.head()
# Out:
#    survived  pclass     sex    age  sibsp  parch     fare embarked deck
# 0         0       3    male  264.0      1      0   7.2500        S  NaN
# 1         1       1  female  504.0      1      0  71.2833        C    C
# 2         1       3  female  504.0      0      0   7.9250        S  NaN
# 3         1       1  female  504.0      1      0  53.1000        S    C
# 4         0       3    male  420.0      0      0   8.0500        S  NaN

# %%
titanic.loc[:, "age"] = titanic.loc[:, "age"] / 12
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  42.0      1      0  71.2833        C    C
# 2         1       3  female  42.0      0      0   7.9250        S  NaN
# 3         1       1  female  42.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
index_babies = titanic.loc[titanic.age < 1].index
index_babies
# Out:
# Int64Index([78, 305, 469, 644, 755, 803, 831], dtype='int64')

# %%
titanic_babies = titanic.loc[index_babies]

# %%
titanic_babies
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  0.83      0      2   29.0000        S  NaN
# 305         1       1    male  0.92      1      2  151.5500        S    C
# 469         1       3  female  0.75      2      1   19.2583        C  NaN
# 644         1       3  female  0.75      2      1   19.2583        C  NaN
# 755         1       2    male  0.67      1      1   14.5000        S  NaN
# 803         1       3    male  0.42      0      1    8.5167        C  NaN
# 831         1       2    male  0.83      1      1   18.7500        S  NaN

# %%
titanic_babies['age'] = titanic_babies['age'].apply(lambda x: x + 1)
titanic_babies
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.83      0      2   29.0000        S  NaN
# 305         1       1    male  1.92      1      2  151.5500        S    C
# 469         1       3  female  1.75      2      1   19.2583        C  NaN
# 644         1       3  female  1.75      2      1   19.2583        C  NaN
# 755         1       2    male  1.67      1      1   14.5000        S  NaN
# 803         1       3    male  1.42      0      1    8.5167        C  NaN
# 831         1       2    male  1.83      1      1   18.7500        S  NaN

# %%
def sum_one(i):
    return i+1

# %%
titanic_babies['fare'] = titanic_babies['fare'].apply(sum_one)
titanic_babies
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 78          1       2    male  1.83      0      2   30.0000        S  NaN
# 305         1       1    male  1.92      1      2  152.5500        S    C
# 469         1       3  female  1.75      2      1   20.2583        C  NaN
# 644         1       3  female  1.75      2      1   20.2583        C  NaN
# 755         1       2    male  1.67      1      1   15.5000        S  NaN
# 803         1       3    male  1.42      0      1    9.5167        C  NaN
# 831         1       2    male  1.83      1      1   19.7500        S  NaN
